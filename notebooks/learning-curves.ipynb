# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black

# %%
import os

os.chdir("..")
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import tqdm.auto as tqdm

from orthogonal_dfa.experiments.training_curves import (
    plot_training_curves,
    plot_sparsity_curves,
)
from orthogonal_dfa.experiments.trained_models import all_models

# %%
results = [x.results for x in tqdm.tqdm(all_models)]
# Out:
# ...
# Training Gates:  80%|########  | 8/10 [00:10<00:02,  1.33s/it]

# %%
plot_training_curves(results, [x.name for x in all_models])

# %%
plot_sparsity_curves(all_models)
