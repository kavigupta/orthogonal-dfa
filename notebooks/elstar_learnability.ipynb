# %%
from orthogonal_dfa.analysis.elstar_learnability import (
    learnability_bars,
    plot_learnability,
)

# %%
results = learnability_bars()

# %%
plot_learnability(results);
