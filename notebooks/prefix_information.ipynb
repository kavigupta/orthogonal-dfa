# %%
from orthogonal_dfa.analysis.prefix_information import (
    prefix_information_bars,
    plot_prefix_information,
)

# %%
results = prefix_information_bars()

# %%
plot_prefix_information(results);
