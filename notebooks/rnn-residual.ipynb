# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black

# %%
import os

os.chdir("..")
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
from matplotlib import pyplot as plt
from orthogonal_dfa.experiments.pdfa_residual import (
    do_plot_last,
    no_orf,
    compute_all_original_and_residual_by_sparsity,
    plot_residual_results_by_sparsity,
)
from orthogonal_dfa.experiments.trained_models import (
    rnn_models_main,
    r_rnn_500_1l_sparse_10_psams_more_epochs,
)

# %%
x = rnn_models_main[-1].results

# %%
plt.figure(dpi=200, figsize=(10, 10))
for m in rnn_models_main:
    do_plot_last(no_orf, m.results, m.name)
plt.grid()
plt.ylabel("Signal in RNN")
plt.xlabel("Remaining signal in no-ORF | RNN")
plt.show()

# %%
r = r_rnn_500_1l_sparse_10_psams_more_epochs.results
orrbs = compute_all_original_and_residual_by_sparsity(r)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]

# %%
plot_residual_results_by_sparsity(orrbs)
