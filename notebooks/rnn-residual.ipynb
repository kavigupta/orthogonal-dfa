# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyter_black

# %%
import os

os.chdir("..")
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from matplotlib import pyplot as plt
from orthogonal_dfa.experiments.pdfa_residual import do_plot_last, no_orf
from orthogonal_dfa.experiments.trained_models import rnn_models_main

# %%
x = rnn_models_main[-1].results

# %%
plt.figure(dpi=200, figsize=(10, 10))
for m in rnn_models_main:
    do_plot_last(no_orf, m.results, m.name)
plt.grid()
# Out:
# Training Gates:  80%|########  | 8/10 [00:10<00:02,  1.29s/it]
